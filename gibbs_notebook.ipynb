# %%
from gibbs import GibbsDataset

from dataset import Synthetic_data
import numpy as np
from scipy.stats import multivariate_normal, invwishart, beta, truncnorm
from dataset_initialisation import GMM_Init
from matplotlib import pyplot as plt

# %%
N_t = 1000
K = 2
gibbs = GibbsDataset(N_t, K)
gibbs.gibbs_sampler(max_iters=100)
# Out:
# /Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/year_4/M4R/weighted_VI_code/spectral_clustering_weighted_VI/gibbs.py:68: RuntimeWarning: invalid value encountered in divide
#   z_probs = z_probs / np.sum(z_probs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 K = 2
#       3 gibbs = GibbsDataset(N_t, K)
# ----> 4 gibbs.gibbs_sampler(max_iters=100)
#
# File ~/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/year_4/M4R/weighted_VI_code/spectral_clustering_weighted_VI/gibbs.py:180, in GibbsDataset.gibbs_sampler(self, max_iters)
#     175 self.prior_scale_mat = np.mean(gmm.cluster_covs, axis=0)
#     178 for t in range(max_iters):
#     179     # Update z
# --> 180     new_z = [self.z_update(i) for i in range(self.N_t)]
#     181     self.z_samples.append(new_z)
# ...

# %%
import matplotlib.pyplot as plt

# Example initialization (replace with your actual data structure)
# mean_samples = [[[[1, 2], [3, 4]], [[1.5, 2.5], [3.5, 4.5]], ...]]

# Set up the plot
plt.figure(figsize=(10, 6))
plt.title('Scatter Plot of Mean Samples by Group')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.grid(True)

# Color or marker for each group
markers = ['o', 's']  # 'o' for circles, 's' for squares, add more if there are more groups
colors = ['blue', 'red']  # Blue for group 1, red for group 2, add more colors if needed

#print(gibbs.mean_samples)

for sample in gibbs.mean_samples:
    g1 = sample[0]
    g2 = sample[1]
    plt.scatter(g1[0], g1[1], color='blue', marker='o')
    plt.scatter(g2[0], g2[1], color='red', marker='s')

# Plot each group with different colors/markers
plt.legend()
plt.show()

# Assuming you have an instance of your Gibbs sampler named 'gibbs'
# Uncomment and use the following line when you have your actual gibbs instance
# plot_grouped_mean_samples(gibbs.mean_samples)
# Out:
# /var/folders/c3/91bqt9g14t73pxvtc2mr0xg00000gn/T/ipykernel_87451/3982920487.py:26: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plot_grouped_mean_samples(gibbs.mean_samples)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_grouped_mean_samples(gibbs.mean_samples)
#
# Cell In[6], line 21, in plot_grouped_mean_samples(mean_samples)
#      19 for iteration in mean_samples:
#      20     for group_index, (group_means) in enumerate(iteration):
# ---> 21         x_vals = [mean[0] for mean in group_means]  # First dimension
#      22         y_vals = [mean[1] for mean in group_means]  # Second dimension
#      23         plt.scatter(x_vals, y_vals, alpha=0.6, edgecolors='w',
#      24                     color=colors[group_index % len(colors)],
#      25                     marker=markers[group_index % len(markers)],
#      26                     label=f'Group {group_index+1}' if len(plt.gca().get_legend_handles_labels()[1]) <= group_index else "")
#
# IndexError: invalid index to scalar variable.
