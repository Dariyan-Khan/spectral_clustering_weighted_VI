# %%
from r_dist import R
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define the range of alpha values, starting slightly above 0 to avoid division by zero issues
alphas = np.linspace(0.1, 1000, 100)  # 100 points from 0.1 to 1000

# Initialize lists to store the results
first_moments = []

# Loop over each alpha value, compute the first moment, and store it
for alpha in alphas:
    r_dist = R(alpha=alpha, beta=1.0, d=3)  # Assuming beta and d are fixed
    first_moments.append(r_dist.first_moment)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(alphas, first_moments, label='First Moment of r', marker='o')
plt.title('First Moment of r vs. Alpha')
plt.xlabel('Alpha')
plt.ylabel('First Moment of r')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from r_dist import R

# Define the range of alpha values, starting slightly above 0 to avoid division by zero issues
alphas = np.linspace(0.1, 1000, 100)  # 100 points from 0.1 to 1000

# Initialize lists to store the results
differences = []

# Loop over each alpha value, compute the difference, and store it
for alpha in alphas:
    r_dist = R(alpha=alpha, beta=1.0, d=3)  # Assuming beta and d are fixed
    differences.append(1 - r_dist.first_moment)

# Plotting on a logarithmic scale
plt.figure(figsize=(10, 6))
plt.plot(alphas, differences, label='1 - First Moment of r')
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.title('Difference Between 1 and First Moment of r vs. Alpha on Log Scale')
plt.xlabel('Alpha')
plt.ylabel('1 - First Moment of r')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from r_dist import R

# Define the range of alpha values, starting slightly above 0 to avoid division by zero issues
alphas = np.linspace(0.1, 1000, 100)  # 100 points from 0.1 to 1000

# Initialize lists to store the results
differences = []

# Loop over each alpha value, compute the difference, and store it
beta = 1.0
for alpha in alphas:
    r_dist = R(alpha=alpha, beta=beta, d=3)  # Assuming beta and d are fixed
    differences.append(np.abs(beta - r_dist.first_moment))
    #differences.append(np.abs(r_dist.second_moment))

# Plotting with the y-axis on a logarithmic scale
plt.figure(figsize=(10, 6))
plt.plot(alphas, differences, label='1 - First Moment of r')
plt.yscale('log')  # Set y-axis to logarithmic scale
#
plt.xlabel('Alpha')
plt.ylabel('β - first Moment of r (Log Scale)')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from r_dist import R  # Ensure you have this module or adjust accordingly

# Define the range of alpha values, starting slightly above 0 to avoid division by zero issues
alphas = np.linspace(0.1, 1000, 200)  # 100 points from 0.1 to 1000

# List of beta values
betas = [ -0.5, -0.2, -0.1, 0.5, 1.0, 2.0]

# Initialize lists to store the results for each beta
results = {}

for beta in betas:
    differences = []
    for alpha in alphas:
        try:
            r_dist = R(alpha=alpha, beta=beta, d=3)  # Assuming d is fixed
        except ValueError:
            print(f'Error: alpha={alpha}, beta={beta}')
            assert False

        differences.append(np.abs(max(beta,0) - r_dist.first_moment))
    results[beta] = differences

# Plotting with the y-axis on a logarithmic scale
fig, ax = plt.subplots(figsize=(8.4, 5.0))

for beta, differences in results.items():
    ax.plot(alphas, differences, label=f'β = {beta}')

ax.set_yscale('log')  # Set y-axis to logarithmic scale
ax.set_xlabel('α', fontsize=10)
ax.set_ylabel('max(β,0) - first moment of r (Log Scale)', fontsize=10)
ax.grid(True)
ax.legend(fontsize=8)

# Applying publication quality settings
plt.rc('font', size=8)  # Default text sizes
plt.rc('axes', titlesize=8)  # Axes title font size
plt.rc('legend', fontsize=8)  # Legend font size
plt.rc('xtick', labelsize=10)  # X-axis tick label font size
plt.rc('ytick', labelsize=10)  # Y-axis tick label font size
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
plt.tight_layout()

# Save the figure in PDF format with high quality
plt.savefig('plot.pdf', bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from r_dist import R  # Ensure you have this module or adjust accordingly

# Define the range of alpha values, starting slightly above 0 to avoid division by zero issues
alphas = np.linspace(0.1, 1000, 200)  # 100 points from 0.1 to 1000

# List of beta values
betas = [ -0.5, -0.2, -0.1, 0.5, 1.0, 2.0]

# Initialize lists to store the results for each beta
results = {}

for beta in betas:
    differences = []
    for alpha in alphas:
        try:
            r_dist = R(alpha=alpha, beta=beta, d=3)  # Assuming d is fixed
        except ValueError:
            print(f'Error: alpha={alpha}, beta={beta}')
            assert False

        differences.append(np.abs(r_dist.second_moment))
    results[beta] = differences

# Plotting with the y-axis on a logarithmic scale
fig, ax = plt.subplots(figsize=(8.4, 5.0))

for beta, differences in results.items():
    ax.plot(alphas, differences, label=f'β = {beta}')

ax.set_yscale('log')  # Set y-axis to logarithmic scale
ax.set_xlabel('α', fontsize=10)
ax.set_ylabel('second moment of r (Log Scale)', fontsize=10)
ax.grid(True)
ax.legend(fontsize=8)

# Applying publication quality settings
plt.rc('font', size=8)  # Default text sizes
plt.rc('axes', titlesize=8)  # Axes title font size
plt.rc('legend', fontsize=8)  # Legend font size
plt.rc('xtick', labelsize=10)  # X-axis tick label font size
plt.rc('ytick', labelsize=10)  # Y-axis tick label font size
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
plt.tight_layout()

# Save the figure in PDF format with high quality
plt.savefig('plot.pdf', bbox_inches='tight')
plt.show()

# %%
from r_dist import R
import numpy as np
import matplotlib.pyplot as plt

r_dist = R(alpha=20.0, beta=-8.0, d=5)
r_dist.first_moment
# Out:
# /Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/year_4/M4R/weighted_VI_code/spectral_clustering_weighted_VI/r_dist.py:27: RuntimeWarning: divide by zero encountered in log
#   self.first_moment = np.exp(np.log(self.compute_Id(order=self.d+1)) - np.log(self.norm_const))
# /Users/dariyankhan/Library/CloudStorage/OneDrive-ImperialCollegeLondon/Work (one drive)/Imperial/year_4/M4R/weighted_VI_code/spectral_clustering_weighted_VI/r_dist.py:27: RuntimeWarning: invalid value encountered in scalar subtract
#   self.first_moment = np.exp(np.log(self.compute_Id(order=self.d+1)) - np.log(self.norm_const))
# nan
